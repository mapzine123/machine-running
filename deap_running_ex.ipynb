# %% [markdown]
# <a href="https://colab.research.google.com/github/mapzine123/machine-running/blob/main/deap_running_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt

diabetes = load_diabetes()
x = diabetes.data[:, 2]
y = diabetes.target
# Out:
# 1.0616962065186832
# 151.0
# 1.0678658271705517
# 0.06169620651868429

# %%
# 그래프 그려보기
plt.scatter(diabetes.data[:, 2], diabetes.target) # 산점도
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# 예측값 : y^ = w*x + b
#
# 훈련 데이터에 잘 맞는 w와 b 찾는 방법
# 1. 무작위로 w와 b를 정함 (무작위로 모델 만들기)
# 2. x에서 샘플 하나를 선택해 y^를 계산(무작위로 모델 예측하기)
# 3. 모델에서 계산된 y^와 실제 y값을 비교 (예측한 값과 진짜 정답 비교하기, 틀릴 확률 99%)
# 4. y^과 y가 더 가까워지도록 w, b 값 조정 (모델 조정하기)
# 5. 모든 샘플을 처리할 때 까지 2 ~ 4 항목 반복

# %%
# 1. w 와 b 값 초기화하기
w = 1.0   # 기울기
b = 1.0   # 절편

# 2. 훈련 데이터의 첫번째 샘플 데이터로 y^ 얻기
y_hat = x[0] * w + b    # y^ = wx + b

# 3. 예측한 값과 진짜 정답 비교하기
print(y_hat) # 1.0616...
print(y[0])  # 151.0

# 4. w 값 조절해 예측값 바꾸기
w_inc = w + 0.1
y_hat_inc = x[0] * w_inc + b
print(y_hat_inc) # 1.0678... (살짝 증가)

# 5. w 값 조정한 후 예측값 증가 정도 확인하기
# w가 0.1만큼 증가했을때 y_hat이 얼마나 증가했는지 계산하려면, y_hat이 증가한 양을 w가 증가한 양으로 나누면 됨
w_rate = (y_hat_inc - y_hat) / (w_inc - w)
print(w_rate) # 0.06169...
# Out:
# 1.0616962065186832
# 151.0
# 1.0678658271705517
# 0.06169620651868429

# %% [markdown]
# # 변화율이 양수일 때 가중치 업데이트 방법
# w가 증가하면 y_hat 증가
#
# # 변화율이 음수일 때 가중치 업데이트 방법
# w가 감소하면 y_hat 증가
#
# 변화율을 더하면 가중치가 업데이트됨
# # w + w_rate

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 변화율로 절편 업데이트하기
b_inc = b + 0.1
y_hat_inc = x[0] * w + b_inc
print(y_hat_inc) # 1.1616...

b_rate = (y_hat_inc - y_hat) / (b_inc - b)
print(b_rate) # 변화율 : 1
# Out:
# 1.1616962065186833
# 1.0

# %% [markdown]
# 변화율이 1이다. 즉, b가 1만큼 증가하면 y_hat도 1만큼 증가함
